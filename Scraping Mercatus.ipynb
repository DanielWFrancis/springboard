# %%
import argparse
import concurrent.futures
import logging
import datetime
import requests
import re
import urllib.error
import itertools
import pprint
import ast
import bs4
import textract
import os
from pathlib import Path
import better_exceptions
import subprocess

ENCODE_IN = 'utf-8'
ENCODE_OUT = 'utf-8'
MAXTRIES = 5
STARTURL="https://www.mercatus.org/tags/federalism"
pubpages = {}
tagpages = {}

#### UTILITY FUNCTIONS #########################################################
## The following functions return a soup object from a URL and perform the 
## gathering of 'tag' links and 'document' links for pages. Both are called by
## functions focusing on both tag and document pages.

def get_soup(url):
    for i in range(MAXTRIES):
        r = requests.get(url)
        r.encoding = ENCODE_IN
        return bs4.BeautifulSoup(r.content, "lxml")

def gather_links(soup):
    
    # This function goes through all the links in a page, finding
    # which ones are complete and which ones need concatenation, and then
    # sorting these links into `tagpages` if they are tag pages and `pubpages`
    # if they are publication pages. The value of 0 is assigned to indicate
    # that the tagpage or pubpage has not yet gone through tagpager or pubpager.
    
    for x in soup.find_all('a', {'href':True}):
        href = x['href']
        if len(href.split('/')) > 3:
            if href.split('/')[3] == "tags" and href not in tagpages and '?' not in href:
                tagpages[href] = 0
            if href.split('/')[3] in ["publication","publications","commentary"] and href not in pubpages \
            and href[:4] == "http" and href.split('/')[2].split('.')[1] == 'mercatus':
                if href[0] == '/':
                    pubpages['https://www.mercatus.org' + href] = 0
                else:
                    pubpages[href] = 0
        if len(href.split('/')) == 3:
            if href.split('/')[1] == "tags" and 'https://www.mercatus.org' + href not in tagpages \
            and '?' not in href:
                tagpages['https://www.mercatus.org' + href] = 0
            if href.split('/')[1] in ["publication","publications","commentary"] \
            and 'https://www.mercatus.org' + href not in pubpages:
                pubpages['https://www.mercatus.org' + href] = 0
                    
#### PAGER FUNCTIONS ###########################################################
## The following functions handle the tag and publication pages, respectively.
## Handling tag pages is a simple matter of collecting all of the links on the
## tag page and sorting them into the `pubpages` and `tagpages` dictionaries.
## Handling publication pages is more complicated, as metadata must be collected
## along with text, and these must be saved to a text file. An additional
## function called `find_and_read_pdfs` extracts text from PDFs for the pubpager
## function.
    
def tagpager(url):
    print('running tagpager on ' + url)
    for x in range(0,3):
        soup = get_soup(url + "?page=" + str(x))
        gather_links(soup)

def pubpager(url):
    print('running pubpager on ' + url)
    tagpattern = re.compile('^\/tags\/')
    soup = get_soup(url)
    
    # first we must extract the type of publication, which helps us extract text below.
    
    try:
        pubtype = soup.find("div", class_="field-name-field-publication-type").text.strip().lower()
    except AttributeError:
        try:
            soup = get_soup(url)
            pubtype = soup.find("div", class_="pane-node-content-type").text.strip().lower()
        except:
            print('Bailing out; error fetching basics on ' + url)
            return
        
    if 'visualization' not in pubtype and 'book' not in pubtype:
        # figure out if this is a commentary or publications document and then extract
        # text using the appropriate method - either directly from the page, or from PDFs.
        
        if url.split("/")[3] == "commentary":
            text = " ".join([x.text for x in soup.find_all("div",class_="field-type-text-with-summary")])
            pub_style = soup.find('div',{'class':'pane-node-content-type'}).text.strip().replace('/','-')
        elif url.split("/")[3] in ["publications","publication"]:
            text = find_and_read_pdfs(soup, url)
            pub_style = soup.find('div',{'class':'field-name-field-publication-type'}).text.strip().replace('/','-')
#             if not text:
#                 return
            if len(text) < 40:
                text = " ".join([x.text for x in soup.find_all("div",class_="field-type-text-with-summary")])
                
        
        # collect title and append the url to the end of the text
        
        title = soup.find('div',class_="pane-node-title").text.strip().replace('/','-')
        text += url
        
        # gather tags - if this fails, we will return out of this function,
        # as the tags are the whole point of this.
        
        try:
            tags=[x.text.replace('/','-') for x in soup.find('div',class_='field-name-field-tags').find_all('a', href=tagpattern)]
        except AttributeError:
            print('Could not find tags for ' + url)
            return
        
        # find the date and author names, formatting them for output
        
        date = soup.find("span",class_="date-display-single").text.strip()
        names = []
        for name in soup.find('div',{'class':'field-name-field-people'}).find_all('h4',{'class':'node-title'}):
            names.extend([name.text])
        if len(names) > 2:
            names = names[:2]
        authors = '--'.join(names)
        
        # for each tag, save a copy of the text to a text file.

        for tag in tags:
            outpath = Path("new_data/" + tag + "/" + authors + "__" + 
                           pub_style + "__" + title + " - " + date + '.txt')
            
            # if the length of the outpath is too long to save, removed 20
            # character from the title and try again.
            
            while len(str(outpath)) > 220:
                title = title[:-20]
                outpath = Path("new_data/" + tag + "/" + authors + "__" + 
                               pub_style + "__" + title + " - " + date + '.txt')
                
            # save the file.
            
            try:
                outpath.parent.mkdir(parents=True, exist_ok=True)
            except FileExistsError:
                pass
            outpath.write_text(text, encoding=ENCODE_OUT)
    
    # always call gather_links to look for additional tag or pub links
    # that are not yet in tagpages or pubpages.
    
    gather_links(soup)

def find_and_read_pdfs(soup, url):
    
    # download pdfs and extract text. if multiple pdfs, then append
    # text from subsequent pdfs to text from first pdf. 
    
    text = " "
    pdfpattern = re.compile("\.pdf$")
    for pdf in soup.find_all('a', href=pdfpattern, title=True):
        with Path('raw/' + pdf['title']).open('wb') as outf:
            if 'http' not in pdf['href']:
                pdf_url = 'http://mercatus.org' + pdf['href']
            else:
                pdf_url = pdf['href']
            outf.write(requests.get(pdf_url).content)
            
    # There are many types of errors that can occur, and this block helps
    # deal with that. So far only about ~60 documents fall into these
    # exceptions, so working out the kinks isn't really worth it.
    
        try:
            text += subprocess.check_output(['pdftotext','-enc','UTF-8','raw/' + pdf['title'],'-'], 
                                           stderr=subprocess.DEVNULL).decode('utf-8', errors="ignore")
            print("Successfully extracted " + pdf['title'])
        except UnicodeDecodeError:
            print("DECODE ERROR OCCURRED ON " + pdf['title'])
        except:
            print("MYSTERY??? ERROR OCCURRED ON " + pdf['title'])
        os.remove('raw/' + pdf['title'])
    
    return " ".join(text.split())

#### CONTROLLER FUNCTIONS ######################################################
## These functions manage the `pubpages` and `tagpages` dictionaries, looking
## for urls with value 0, setting them to 1, and running the necessary pager
## function on that url.
    
def pubcontroller():
    zeroes=[url for url, status in pubpages.items() if status == 0]
    for url in zeroes:
        pubpages[url] = 1
        pubpager(url)

def tagcontroller():
    zeroes=[url for url, status in tagpages.items() if status == 0]
    for url in zeroes:
        tagpages[url] = 1
        tagpager(url)
        
#### MAIN FUNCTION ############################################################
## The main function runs an initial tagpager call on the STARTURL and then
## begins a `while True` loop that breaks only when all pubpages and tagpages
## values are 1. 

def main():
    tagpager(STARTURL)
    while True:
        if 0 in pubpages.values():
            print('running pubcontroller')
            pubcontroller()
        if 0 in tagpages.values():
            print('running tagcontroller')
            tagcontroller()
        if 0 not in pubpages.values() and 0 not in tagpages.values():
            break
            
main()
# Out:
# running tagpager on https://www.mercatus.org/tags/federalism
# running pubcontroller
# running pubpager on https://www.mercatus.org/publication/should-puerto-rico-be-allowed-restructure-its-debt-mercatus-debate
# Successfully extracted Verret-Joffe-Puerto-Rico-Debate-v2.pdf
# running pubpager on https://www.mercatus.org/publication/be-rather-seem-fiscal-responsibility-and-political-economy-north-carolina
# Successfully extracted Miller-Fiscal-Responsibility-NC.pdf
# Successfully extracted Miller-Fiscal-Responsibility-NC-summary.pdf
# running pubpager on https://www.mercatus.org/publication/political-economy-medicaid-expansion-federalism-interest-groups-and-aca
# Successfully extracted Sutter-Medicaid-Expansion-v1.pdf
# Successfully extracted Sutter-Medicaid-Expansion-sum-v1.pdf
# running pubpager on https://www.mercatus.org/publications/capitol-hill-state-house-or-city-hall-debating-location-political-power-and-decision
# running pubpager on https://www.mercatus.org/publications/federal-highway-funding-needs-change
# Successfully extracted krol-federal-highway-funding-mop-mercatus-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/make-infrastructure-pay-itself
# running pubpager on https://www.mercatus.org/publication/freedom-50-states-2013-edition
# running pubpager on https://www.mercatus.org/commentary/feds-consider-reducing-highway-funding-states
# running pubpager on https://www.mercatus.org/publication/federalism-and-constitution-competition-versus-cartels
# running pubpager on https://www.mercatus.org/commentary/having-50-states-bit-drag
# running pubpager on https://www.mercatus.org/publication/vertical-fiscal-gaps-and-economic-performance-theoretical-and-empirical
# Successfully extracted Sorens-Vertical-Fiscal-Gaps-v1.pdf
# Successfully extracted Sorens-Vertical-Fiscal-Gaps-sum-v1.pdf
# running pubpager on https://www.mercatus.org/publication/tolling-freeway-congestion-pricing-and-economics-managing-traffic
# Successfully extracted Krol-Congestion-Pricing-v1.pdf
# Successfully extracted Krol-Congestion-Pricing-sum-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/disaster-recovery-best-knowledge-local-knowledge
# running pubpager on https://www.mercatus.org/commentary/why-conservatives-can-cheer-californias-single-payer-health-care-bill
# running pubpager on https://www.mercatus.org/commentary/theres-no-wizard-behind-curtain
# running pubpager on https://www.mercatus.org/publication/long-term-trends-medicaid-spending-states
# Successfully extracted Joffe-State-Medicaid-Spending.pdf
# Successfully extracted Long-Term-Trends-Medicaid-Summary.pdf
# running pubpager on https://www.mercatus.org/publication/does-pennsylvania-s-redevelopment-assistance-capital-program-develop-its-economy
# Successfully extracted Millsap-PA-RACP-1.pdf
# Successfully extracted Millsap-PA-RACP-research-summary.pdf
# running pubpager on https://www.mercatus.org/publication/property-tax-rates-and-local-government-revenue-growth
# Successfully extracted Ross-Property--Tax-MOP.pdf
# running pubpager on https://www.mercatus.org/commentary/local-government-consolidation-not-panacea
# running pubpager on https://www.mercatus.org/publication/american-federalism-how-well-does-it-support-liberty
# running pubpager on https://www.mercatus.org/publication/two-models-federalism-highlight-growing-divide-among-states
# running pubpager on https://www.mercatus.org/publication/freedom-50-states-2011-edition
# running tagcontroller
# running tagpager on https://www.mercatus.org/tags/state-and-local-budget-reform
# running tagpager on https://www.mercatus.org/tags/economics-and-public-policy
# running tagpager on https://www.mercatus.org/tags/taxes
# running tagpager on https://www.mercatus.org/tags/medicaid
# running tagpager on https://www.mercatus.org/tags/entitlements
# running tagpager on https://www.mercatus.org/tags/healthcare
# running tagpager on https://www.mercatus.org/tags/federalism
# running tagpager on https://www.mercatus.org/tags/regulatory-process-reform
# running tagpager on https://www.mercatus.org/tags/transportation-financing
# running tagpager on https://www.mercatus.org/tags/puerto-rico
# running tagpager on https://www.mercatus.org/tags/regulation
# running tagpager on https://www.mercatus.org/tags/government-accountability
# running tagpager on https://www.mercatus.org/tags/disaster-recovery
# running tagpager on https://www.mercatus.org/tags/barriers-entry
# running tagpager on https://www.mercatus.org/tags/financial-markets
# running tagpager on https://www.mercatus.org/tags/state-state-comparisons
# running tagpager on https://www.mercatus.org/tags/study-american-capitalism
# running tagpager on https://www.mercatus.org/tags/monetary-policy
# running tagpager on https://www.mercatus.org/tags/federal-fiscal-policy
# running tagpager on https://www.mercatus.org/tags/technology-policy
# running tagpager on https://www.mercatus.org/tags/state-and-local-policy
# running tagpager on https://www.mercatus.org/tags/transportation-policy
# running tagpager on https://www.mercatus.org/tags/state-and-local-tax-policy
# running tagpager on https://www.mercatus.org/tags/trade-and-immigration
# running pubcontroller
# running pubpager on https://www.mercatus.org/publications/increased-federal-funding-higher-education-produces-adverse-effects
# running pubpager on https://www.mercatus.org/publications/education-innovation-fiscal-policy-and-state-constitutions
# Successfully extracted primo_-_mop_-_constitutions_and_the_fiscal_health_of_states-education_innovation_-_v1.pdf
# running pubpager on https://www.mercatus.org/publication/flaws-aig-trust-agreement-and-implications-pending-citigroup-and-other-tarp-trusts
# Successfully extracted JW_Verret_-_House_Oversight_5-13-2009.pdf
# running pubpager on https://www.mercatus.org/commentary/why-aca-medicaid-expansion-needs-be-fixed
# running pubpager on https://www.mercatus.org/publication/effect-property-reassessments-fiscal-transparency-and-government-growth-evidence
# Successfully extracted Ross-Fiscal-Illusion.pdf
# running pubpager on https://www.mercatus.org/publication/competition-and-convergence-communications-supplementary-questions-testimony
# Successfully extracted Competetion_and_Convergence_-_Answers_to_Supplemental_Questions.pdf
# running pubpager on https://www.mercatus.org/commentary/floridas-fiscally-responsible-state-government
# running pubpager on https://www.mercatus.org/commentary/fix-federal-spending-baseline-first
# running pubpager on https://www.mercatus.org/publication/elusive-recovery
# running pubpager on https://www.mercatus.org/publication/dreams-deferred-young-workers-and-recent-graduates-us-economy
# Successfully extracted Hall-Millennial-Unemployment-testimony-062414.pdf
# running pubpager on https://ppe.mercatus.org/publication/written-testimony-rebuilding-new-orleans-after-hurricane-katrina
# Successfully extracted 20070628_Written_Testimony_on_Rebuilding_New_Orleans_after_Hurricane_Katrina.pdf
# running pubpager on https://www.mercatus.org/publication/export-import-bank-s-small-business-program-supports-big-companies
# running pubpager on https://www.mercatus.org/commentary/how-wake-sleepwalking-economy
# Could not find tags for https://www.mercatus.org/commentary/how-wake-sleepwalking-economy
# running pubpager on https://www.mercatus.org/commentary/will-colorado-deny-its-residents-access-credit
# running pubpager on https://www.mercatus.org/publication/regulation-growth-and-labor-market-recovery
# Successfully extracted Hall_RegGrowthLaborMarket_testimony.pdf
# running pubpager on https://www.mercatus.org/publication/building-walls-against-bad-infrastructure-policy-new-orleans
# Successfully extracted Building_Walls_Against_Bad_Infrastructure.pdf
# running pubpager on https://www.mercatus.org/publication/american-recovery-and-reinvestment-act-2009-update
# Successfully extracted House Budget Committee Testimony 7.14.10.pdf
# running pubpager on https://www.mercatus.org/publication/expiring-bush-era-tax-cuts-rich-doesnt-get-rid-spending-problem
# running pubpager on https://www.mercatus.org/commentary/paint-numbers-lawmaking-waters-down-tax-reform
# running pubpager on https://www.mercatus.org/commentary/made-america-free-trade-mutually-exclusive
# running pubpager on https://www.mercatus.org/publications/federalism-federalization-fintech
# Successfully extracted mercatus-knight-federalism-fintech-v1.pdf
# Successfully extracted mercatus-knight-federalism-fintech-summary-v1.pdf
# running pubpager on https://www.mercatus.org/publication/better-measures-unemployment
# running pubpager on https://www.mercatus.org/publication/proposed-mortgage-modifications-bankruptcy-code
# Successfully extracted Todd-Zywicki---Written-Testimony-for-the-House-Judiciary-1-22-2009.pdf
# running pubpager on https://www.mercatus.org/publication/affordable-care-acts-optional-medicaid-expansion-considerations-facing-state-governments
# Successfully extracted Blahous_MedicaidExpansion_v1.pdf
# Successfully extracted Blahous-Medicaid-summary-v2_1.pdf
# running pubpager on https://www.mercatus.org/publication/choice-neighborhoods-initiative
# Successfully extracted SandersTestimony.pdf
# running pubpager on https://ppe.mercatus.org/publication/community-revival-wake-disaster
# running pubpager on https://www.mercatus.org/commentary/corporate-vs-government-scandals
# running pubpager on https://www.mercatus.org/publication/lets-return-clinton-era-spending-levels
# running pubpager on https://www.mercatus.org/publication/banking-industry-perspectives-obama-administration-s-financial-regulatory-reform
# Successfully extracted CFPA-Todd-Zywicki-Testimony-7-15-2009.pdf
# running pubpager on https://www.mercatus.org/publications/certificate-of-need-laws-goals
# Successfully extracted mitchell-con-qa-mop-mercatus-v2.pdf
# running pubpager on https://www.mercatus.org/commentary/will-bootleggers-and-baptists-rewrite-nafta
# running pubpager on https://www.mercatus.org/commentary/alaska-showing-how-regulate-ridesharing-right
# running pubpager on https://www.mercatus.org/publication/economic-situation-march-2016
# Successfully extracted Yandle-March-2016-Economic-Situation-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/celebrating-our-independence-export-import-bank
# running pubpager on https://www.mercatus.org/commentary/illinois-becomes-financial-trap-businesses-and-residents
# running pubpager on https://www.mercatus.org/commentary/how-good-tax-reform-goes-bad
# running pubpager on https://www.mercatus.org/publication/sharing-economy-issues-facing-platforms-participants-and-regulators
# Successfully extracted Koopman-Sharing-Economy-FTC-filing.pdf
# running pubpager on https://www.mercatus.org/publication/social-security-and-medicare-programs-remain-unsustainable-paths
# running pubpager on https://www.mercatus.org/publication/inflation-targeting-monetary-policy-regime-whose-time-has-come-and-gone
# Successfully extracted Beckworth-Inflation-Targeting.pdf
# Successfully extracted Beckworth-Inflation-Targeting-summary.pdf
# running pubpager on https://www.mercatus.org/publication/agribusiness-political-donations-and-farm-bill-votes
# running pubpager on https://www.mercatus.org/commentary/patience-still-virtue-regulatory-process
# running pubpager on https://www.mercatus.org/publication/disability-insurance-trust-fund-nears-insolvency
# running pubpager on https://www.mercatus.org/publications/dodd-frank-systemically-important-financial-institution-sifi
# running pubpager on https://www.mercatus.org/publication/testimony-us-export-import-bank
# Successfully extracted deRugy-exim-testimony-062314.pdf
# running pubpager on https://www.mercatus.org/publications/more-battles-licensed-occupations
# Successfully extracted mercatus-timmons-licensed-occupations-v1.pdf
# Successfully extracted mercatus-timmons-licensed-occupations-summary-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/dont-make-disasters-worse
# running pubpager on https://www.mercatus.org/commentary/what-cbo-analysis-partial-aca-repeal-really-means
# running pubpager on https://www.mercatus.org/commentary/how-fintech-can-take-without-getting-hampered-regulations
# running pubpager on https://ppe.mercatus.org/publication/club-goods-and-post-disaster-community-return-0
# running pubpager on https://www.mercatus.org/publication/taxicab-cartels-restrict-entry-market-expense-consumers
# running pubpager on https://www.mercatus.org/publication/economic-situation-september-2016
# Successfully extracted Yandle-September-2016-Economic-Situation-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/tale-three-people-disasters-wake
# running pubpager on https://www.mercatus.org/commentary/dont-hamper-disaster-recovery
# running pubpager on https://www.mercatus.org/publications/cultural-and-institutional-barriers-smarter-regulation
# Successfully extracted ellig-house-water-environment-2017-testimony-v1.pdf
# running pubpager on https://www.mercatus.org/publication/congressional-regulatory-oversight-beach
# Successfully extracted Beach-Greater-Congressional-Presence-House-Judiciary-testimony-v1.pdf
# Successfully extracted beach-regulation-oversight-qfr-v1.pdf
# running pubpager on https://www.mercatus.org/publications/federalism-fintech-prosperity-unleashed
# running pubpager on https://www.mercatus.org/commentary/morality-price-gouging
# running pubpager on https://www.mercatus.org/commentary/enterprise-fund-gives-texans-money-their-competitors
# running pubpager on https://www.mercatus.org/publications/efforts-reduce-trade-deficit-will-have-unintended-negative-consequences
# Successfully extracted griswold-trade-deficit-pic-v1.pdf
# running pubpager on https://www.mercatus.org/publications/initiatives-cluttered-colorado-constitution
# Successfully extracted primo_-_mop_-_constitutions_and_the_fiscal_health_of_states-colorado_-_v1.pdf
# running pubpager on https://www.mercatus.org/commentary/ignoring-future-wont-forestall-it
# running pubpager on https://www.mercatus.org/commentary/bitcoins-2x-resolution-shows-self-governance-alive-and-well
# running pubpager on https://www.mercatus.org/publication/written-testimony-medical-debt-and-bankruptcy
# Successfully extracted 20070718_Zywicki_-_Medical_Bankruptcies_Testimony_July_17_2007.pdf
# running pubpager on https://www.mercatus.org/publication/role-streamlining-commissions-bringing-spending-line-revenue-learning-virginia-and
# Successfully extracted Rothschild_PA_testimony_March2011.pdf
# running pubpager on https://www.mercatus.org/publication/restoring-freedom-contract-between-doctor-and-patient-medicare-part-b
# Successfully extracted Bernstein-Medicare-Freedom-of-Contract.pdf
# Successfully extracted Bernstein-Medicare-Freedom-of-Contract-summary.pdf
# running pubpager on https://www.mercatus.org/publication/state-level-job-loss-start-recession
# running pubpager on https://www.mercatus.org/publication/occupational-licensing-and-asymmetric-information-post-hurricane-evidence-florida
# running pubpager on https://www.mercatus.org/publication/deregulation-works-monthly-mobile-phone-bills-hold-steady-while-capital-investment
# running pubpager on https://www.mercatus.org/publications/use-it-or-lose-it-spending-rules-reform
# Successfully extracted fichtner_-_testimony_-_reforming_27use_it_or_lose_it27_rules_-_v1.pdf
# running pubpager on https://www.mercatus.org/commentary/interstate-competition-isnt-magic-health-care-elixir
# running pubpager on https://www.mercatus.org/publications/reforming-tax-preferences-pay-tax-reform
# Successfully extracted derugy-tax-reform-mop-mercatus-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/politics-weird-right-now-business-isnt
# Could not find tags for https://www.mercatus.org/commentary/politics-weird-right-now-business-isnt
# running pubpager on https://www.mercatus.org/publication/social-security-disability-insurance-program-financially-unsustainable-ssdi
# running pubpager on https://www.mercatus.org/publication/fiscal-health-tax-climate-and-best-practices-budgeting
# Successfully extracted Norcross_PA-Fiscal--Condition-Testimony.pdf
# running pubpager on https://www.mercatus.org/publication/dynamic-competition-and-public-policy
# running pubpager on https://www.mercatus.org/publication/economic-way-thinking-13th-edition
# running pubpager on https://www.mercatus.org/commentary/government-barriers-private-solutions
# running pubpager on https://www.mercatus.org/publication/united-states-world-s-leader-international-arms-sales
# running pubpager on https://www.mercatus.org/commentary/get-rid-big-housings-big-break
# running pubpager on https://ppe.mercatus.org/publication/adam-smith-institutes-beginners-guide-liberty
# running pubpager on https://www.mercatus.org/publication/medicare-role-determining-prices-throughout-health-care-system
# Successfully extracted Feldman-Medicare-Role-Prices-oct.pdf
# Successfully extracted Feldman-Medicare-Role-Prices-summary.pdf
# running pubpager on https://www.mercatus.org/publication/case-internet-optimism-part-2
# running pubpager on https://www.mercatus.org/publication/independent-payment-advisory-board
# Successfully extracted Capretta-Independent-Payment-Advisory-Board-MOP-v1.pdf
# running pubpager on https://www.mercatus.org/publication/do-consumer-drones-endanger-national-airspace-evidence-wildlife-strike-data
# Successfully extracted Dourado-Wildlife-Strikes-MOP-v2.pdf
# running pubpager on https://www.mercatus.org/commentary/trumps-appointments-fed-could-affect-global-economy
# running pubpager on https://www.mercatus.org/publication/written-testimony-preparations-2010-census-bureau-ready-job-ahead
# Successfully extracted 20070718_MC_MM_HSGA_Testimony_071707.pdf
# running pubpager on https://www.mercatus.org/commentary/no-one-knows-how-much-costs-we-individually-impose-healthcare-system-and-thats-huge
# running pubpager on https://www.mercatus.org/publications/trouble-brewing-brewer-and-wholesaler-laws-restrict-craft-breweries
# Successfully extracted burgdorf-trouble-brewing-mop-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/border-adjustment-tax-really-dead
# running pubpager on https://www.mercatus.org/publication/can-we-grow-our-way-out-debt
# running pubpager on https://www.mercatus.org/publication/change-dependency-and-regime-plasticity-offshore-financial-intermediation
# running pubpager on https://www.mercatus.org/publication/written-testimony-first-responder-communications-submitted-house-committee-energy-and
# Successfully extracted 20070626_Interoperability_Testimony(1).pdf
# running pubpager on https://www.mercatus.org/commentary/end-net-neutrality-isnt-end-world
# running pubpager on https://ppe.mercatus.org/publication/can-decentralized-bottom-post-disaster-recovery-be-effective
# Successfully extracted Can Decentralized Bottom-Up Post-Disaster Recovery be Effective.pdf
# running pubpager on https://www.mercatus.org/commentary/innovation-not-insurance-health-cares-key
# running pubpager on https://www.mercatus.org/commentary/certificate-need-programs-backfire
# running pubpager on https://www.mercatus.org/publications/alaska-ridesharings-last-frontier
# Successfully extracted farren-alaska-ridesharing-testimony-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/medicaid-expansion-causes-surge-er-visits
# running pubpager on https://www.mercatus.org/commentary/immigration-and-matching-unfilled-jobs-unfulfilled-young-people
# running pubpager on https://www.mercatus.org/publication/freedom-our-most-important-asset
# running pubpager on https://www.mercatus.org/commentary/decentralize-financial-regulation
# running pubpager on https://www.mercatus.org/commentary/3-actions-combatting-government-favoritism
# running pubpager on https://www.mercatus.org/publications/airport-noise-nimbyism
# Successfully extracted dourado-airport-noise-mop-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/hurricane-harvey-relief-comes-extra-large-side-pork
# running pubpager on https://www.mercatus.org/publication/david-vs-godzilla-oira-and-federal-agencies
# Successfully extracted Williams-OIRA-Testimony-v1.pdf
# running pubpager on https://www.mercatus.org/publication/medicare-costs-expected-double-2040
# running pubpager on https://www.mercatus.org/publication/central-bank-intervention-and-role-political-connections
# Successfully extracted Blau_CentralBankIntervention_v1.pdf
# Successfully extracted Blau_CentralBankIntervention_RS_102313.pdf
# running pubpager on https://www.mercatus.org/publications/snapshot-maryland-regulation-2017
# Successfully extracted broughel_and_francis_-_policy_brief_-_regulatory_snapshot_md_-_v2.pdf
# running pubpager on https://www.mercatus.org/commentary/last-ditch-aca-repeal-worth-taking-seriously
# running pubpager on https://www.mercatus.org/publication/latest-improper-payments-figures-show-continuing-problem
# running pubpager on https://www.mercatus.org/publication/hearing-short-termism-financial-markets
# Successfully extracted JW-Testimony---Short-termism---4-28-2010.pdf
# running pubpager on https://www.mercatus.org/commentary/incentives-are-all-wrong-single-payer-health-care
# running pubpager on https://www.mercatus.org/publication/updated-comparison-bls-alternative-national-unemployment-rates
# running pubpager on https://www.mercatus.org/commentary/reasons-euro-again
# running pubpager on https://www.mercatus.org/commentary/republican-ban-internet-gambling-would-repeat-costly-democratic-mistake
# running pubpager on https://www.mercatus.org/publications/broadband-deployment-recommendations-united-states
# Successfully extracted skorup_-_policy_spotlight_-_broadband_deployment_-_v1.pdf
# running pubpager on https://www.mercatus.org/publication/dodd-frank-what-it-does-and-why-its-flawed
# running pubpager on https://www.mercatus.org/publications/effects-occupational-licensure-competition-consumers-and-workforce
# Successfully extracted mclaughlin_mitchell_and_philpot_-_mop_-_the_effects_of_occupational_licensure_comments_for_the_ftc_-_v1.pdf
# running pubpager on https://www.mercatus.org/commentary/spectrum-next-frontier-infrastructure
# running pubpager on https://www.mercatus.org/commentary/economic-phenomenon-making-government-sick
# running pubpager on https://www.mercatus.org/publication/transition-costs-and-public-employee-pension-reform
# Successfully extracted Biggs-PA-testimony-2.pdf
# running pubpager on https://www.mercatus.org/publications/baggage-consumer-installment-cash-lending
# Successfully extracted mercatus-durkin-installment-cash-lending-v1.pdf
# Successfully extracted mercatus-durkin-installment-cash-lending-summary-v1.pdf
# running pubpager on https://www.mercatus.org/publication/why-banks-should-beware-misbehaving
# Successfully extracted Smith-Banks-Misbehaving-MOP-v1.pdf
# running pubpager on https://www.mercatus.org/publications/declining-male-labor-force-participation-jobs
# Successfully extracted winship_malelaborparticipation_mr_v2.pdf
# Successfully extracted winship_malelaborparticipation_mr-rs_media_v2.pdf
# running pubpager on https://www.mercatus.org/publications/would-more-infrastructure-spending-stimulate-economy-2017
# Successfully extracted mercatus-derugy-infrastructure-v2.pdf
# Successfully extracted derugy-mitchell-infrastructure-mr-summary-v1.pdf
# running pubpager on https://www.mercatus.org/publication/taking-institutions-seriously
# running pubpager on https://www.mercatus.org/publication/biggest-beneficiaries-ex-im-bank
# running pubpager on https://www.mercatus.org/publications/integrating-drones-US-air-traffic-control-system
# Successfully extracted mercatus-holcombe-integrating-drones-v1.pdf
# Successfully extracted mercatus-holcombe-integrating-drones-sum-v1.pdf
# running pubpager on https://www.mercatus.org/publications/americas-high-corporate-income-tax-rate-harms-global-competitiveness
# running pubpager on https://www.mercatus.org/commentary/land-use-inclusionary-zoning
# running pubpager on https://www.mercatus.org/publications/generational-equity-and-social-security-financing-reform
# Successfully extracted schieber-social-security-financing-sum-mercatus-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/economy-needs-immigrants
# running pubpager on https://www.mercatus.org/publications/comment-federal-automated-vehicles-policy
# Successfully extracted mercatus-thierer-automated-vehicles-v1.pdf
# running pubpager on https://www.mercatus.org/publication/update-social-security-remains-unsustainable-path
# running pubpager on https://www.mercatus.org/commentary/how-many-jobs-does-aca-kill
# running pubpager on https://www.mercatus.org/publication/creative-destruction-how-globalization-changing-worlds-cultures
# running pubpager on https://www.mercatus.org/publications/state-occupational-licensure-illinois
# Successfully extracted mercatus-mclaughlin-occupation-licensure-illinois-mop-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/housing-prices-are-rising-and-technology-contributing
# running pubpager on https://www.mercatus.org/commentary/north-carolina-better-without-public-broadband
# running pubpager on https://www.mercatus.org/publication/indexing-affordable-care-act-impact-federal-budget
# Successfully extracted Capretta-Indexing-ACA.pdf
# Successfully extracted Capretta-Indexing-ACA-summary.pdf
# running pubpager on https://www.mercatus.org/publications/snapshot-connecticut-regulation-2017
# Successfully extracted broughel_and_francis_-_policy_brief_-_regulatory_snapshot_ct_-_v1.pdf
# running pubpager on https://www.mercatus.org/commentary/trump-still-has-chance-strike-blow-against-special-interests
# running pubpager on https://www.mercatus.org/commentary/open-gates
# running pubpager on https://www.mercatus.org/commentary/strong-jobs-data-usually-means-high-wages-not-time
# running pubpager on https://www.mercatus.org/publication/trends-eitc-spending-and-numbers-beneficiaries
# running pubpager on https://www.mercatus.org/publication/balanced-budget-amendment-constitution
# Successfully extracted A-Balanced-Budget-Amendment.pdf
# running pubpager on https://www.mercatus.org/publication/creating-environment-permissionless-innovation-unmanned-aircraft
# Successfully extracted Dourado-Permissionless-Innovation-Drones-Testimony-v1.pdf
# running pubpager on https://www.mercatus.org/publication/monetary-policy-origins-eurozone-crisis
# Successfully extracted Beckworth-Eurozone-Crisis-v1.pdf
# Successfully extracted Beckworth-Eurozone-Crisis-sum-v1.pdf
# running pubpager on https://www.mercatus.org/publication/austrian-law-and-economics
# running pubpager on https://www.mercatus.org/commentary/getting-federal-disaster-assistance-too-difficult
# running pubpager on https://ppe.mercatus.org/commentary/appeal-moderation
# Could not find tags for https://ppe.mercatus.org/commentary/appeal-moderation
# running pubpager on https://www.mercatus.org/publication/us-health-care-spending-more-twice-average-developed-countries
# running pubpager on https://www.mercatus.org/publication/tracing-roots-today-s-fiscal-policy
# running pubpager on https://www.mercatus.org/publication/can-budget-process-reforms-produce-better-budget-outcomes
# Successfully extracted McTigue-Senate-Budget-Committee-Testimony-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/healthcare-costs-are-reason-youre-not-getting-raise
# Could not find tags for https://www.mercatus.org/commentary/healthcare-costs-are-reason-youre-not-getting-raise
# running pubpager on https://www.mercatus.org/commentary/fairness-and-innovation-apply-same-rules-taxis-ride-shares
# running pubpager on https://www.mercatus.org/publication/job-market-and-great-recession
# Successfully extracted Russ-Roberts---JEC--12-10-09.pdf
# running pubpager on https://www.mercatus.org/commentary/americas-highways-and-bridges-arent-exactly-crumbling
# running pubpager on https://www.mercatus.org/publications/american-balance-of-trade
# Successfully extracted mercatus-griswold-balance-of-trade-v2.pdf
# Successfully extracted mercatus-griswold-balance-of-trade-sum-v1.pdf
# Successfully extracted petroleum_and_non-petroleum_pg._20_recived_colors.pdf
# Successfully extracted us_savings_investments_and_exports_chart_pg._18.pdf
# running pubpager on https://www.mercatus.org/publications/recourse-rule-regulatory-arbitrage-financial-crisis
# Successfully extracted miller-recourse-rule-crisis-wp-mercatus-v1.pdf
# Successfully extracted miller-recourse-rule-crisis-sum-mercatus-v1.pdf
# running pubpager on https://www.mercatus.org/publication/addressing-concerns-about-integrity-us-department-labors-jobs-reporting
# Successfully extracted Keith-Hall-Testimony-June-6-2012.pdf
# running pubpager on https://www.mercatus.org/publication/new-population-bomb
# running pubpager on https://www.mercatus.org/publication/timely-targeted-and-temporary-analysis-government-expansions-over-past-century
# Successfully extracted Taylor-Timely-Targeted-Temporary.pdf
# Successfully extracted Taylor-Timely-Targeted-Temporary-summary.pdf
# running pubpager on https://www.mercatus.org/publications/reforming-financial-regulators
# running pubpager on https://www.mercatus.org/publication/us-corporate-income-tax-now-highest-among-advanced-economies
# running pubpager on https://www.mercatus.org/publication/underfunded-pensions-expanding-and-escalating-challenge
# Successfully extracted mercatus-warshawsky-norcross-underfunded-pensions-v2.pdf
# running pubpager on https://www.mercatus.org/commentary/regulatory-reform-build-what-works
# running pubpager on https://www.mercatus.org/publication/evolving-role-usda-food-and-agricultural-economy
# Successfully extracted Lusk-USDA-v1.pdf
# Successfully extracted Lusk-USDA-sum-v1.pdf
# running pubpager on https://www.mercatus.org/publications/cfpb-rule-payday-title-loans
# Successfully extracted miller-payday-lending-pic-v2.pdf
# running pubpager on https://www.mercatus.org/publication/reforming-retirement-income-annuitization-combination-strategies-and-required-minimum
# Successfully extracted Warshawsky-Combination-Retirement.pdf
# Successfully extracted Warshawsky-Combination-Retirement-summary.pdf
# running pubpager on https://www.mercatus.org/publication/uncertainty-over-growth-health-care-costs
# running pubpager on https://www.mercatus.org/publications/mississippis-certificate-need-law
# Successfully extracted mitchell_-_mississippi27s_certificate-of-need_law_-_v2.pdf
# running pubpager on https://www.mercatus.org/publication/environmental-protection-agencys-fiscal-2008-budget-request
# Successfully extracted 20070301_McTigueTestimony_EPABudgetRequest_03012007.pdf
# running pubpager on https://www.mercatus.org/commentary/price-gouging-laws-not-hurricanes-empty-stores-shelves
# running pubpager on https://www.mercatus.org/publication/some-measures-progressiveness-us-tax-code
# running pubpager on https://www.mercatus.org/commentary/how-states-can-still-outmatch-occ-over-fintech
# running pubpager on https://www.mercatus.org/publications/snapshot-wisconsin-regulation-2017
# Successfully extracted broughel-snapshot-wisconsin-regulation-mercatus-v1.pdf
# running pubpager on https://www.mercatus.org/publication/political-incentives-and-transportation-funding
# Successfully extracted Krol-Transportation-Funding.pdf
# Successfully extracted Krol-Transportation-Funding-sum.pdf
# running pubpager on https://www.mercatus.org/publication/ryan-plan-and-cbo-numbers-compared
# running pubpager on https://www.mercatus.org/publication/trillion-dollar-deficits
# running pubpager on https://www.mercatus.org/publication/constitutional-solutions-our-escalating-national-debt-examining-balanced-budget
# Successfully extracted Primo-budget-amendment-testimony.pdf
# Successfully extracted Primo-budget-amendment-appendix-1.pdf
# Successfully extracted Primo-budget-amendment-appendix-2.pdf
# Successfully extracted Primo-budget-amendment-appendix-3.pdf
# running pubpager on https://www.mercatus.org/commentary/trump-wants-non-economist-lead-fed-could-be-dangerous
# running pubpager on https://www.mercatus.org/publication/transparency-and-accountability-louisiana
# Successfully extracted Louisiana_Testimony__Final.pdf
# running pubpager on https://www.mercatus.org/publication/us-government-dominant-shareholder-how-should-taxpayers-ownership-rights-be-exercised
# Successfully extracted JW-Verret-OGR-Testimony-12_16_09.pdf
# running pubpager on https://www.mercatus.org/publications/technology-schools-e-rate-spending
# Successfully extracted mercatus-skorup-e-rate-technology-mop-2017-v1.pdf
# Could not find tags for https://www.mercatus.org/publications/technology-schools-e-rate-spending
# running pubpager on https://www.mercatus.org/commentary/aca-uninsuring-insured
# running pubpager on https://ppe.mercatus.org/publication/how-we-came-back
# running pubpager on https://www.mercatus.org/publication/new-ideas-refinancing-and-restructuring-mortgage-loans
# Successfully extracted New Ideas for Refinancing and Restructuring Mortgage Loans.pdf
# running pubpager on https://www.mercatus.org/publication/federal-entitlement-spending-multiplies
# running pubpager on https://www.mercatus.org/commentary/few-ways-trump-administration-could-help-minorities
# running pubpager on https://www.mercatus.org/publication/export-import-still-boeing-s-bank
# running pubpager on https://www.mercatus.org/publications/tax-extenders
# Successfully extracted mercatus-de_rugy-michel-tax-extenders-v1.pdf
# running pubpager on https://www.mercatus.org/publications/matter-modernization-media-regulation
# Successfully extracted skorup-fcc-media-regulations-comment-v1.pdf
# running pubpager on https://www.mercatus.org/publication/how-we-came-back
# running pubpager on https://www.mercatus.org/publication/measuring-content-not-just-number-executive-orders-and-proclamations
# running pubpager on https://www.mercatus.org/publication/small-banks-numbers-2000-2014
# running pubpager on https://www.mercatus.org/commentary/will-trumps-2-1-executive-order-lead-dynamic-scoring-regulations
# running pubpager on https://www.mercatus.org/publication/statement-hr-1098-free-competition-currency-act-2011
# Successfully extracted STATEMENT-ON-HR-1098-THE-FREE-COMPETITION-IN-CURRENCY-ACT-OF-2011.pdf
# running pubpager on https://www.mercatus.org/publication/benefits-challenges-and-potential-roles-government-fostering-advancement-internet-things
# Successfully extracted Thierer-NTIA-Filing-IoT-v1.pdf
# running pubpager on https://www.mercatus.org/publication/government-spending-bipartisan-problem-rise-total-capita-mandatory-discretionary-and-net
# running pubpager on https://www.mercatus.org/publication/no-correlation-between-state-unemployment-time-arra-and-stimulus-funds-received
# running pubpager on https://www.mercatus.org/publication/bitcoin-manual-basico-para-legisladores-y-disenadores-de-politicas
# running pubpager on https://www.mercatus.org/commentary/digital-life-no-room-hide
# running pubpager on https://www.mercatus.org/commentary/europes-muslims-are-more-integrated-you-think
# running pubpager on https://www.mercatus.org/publications/did-deregulation-cause-financial-crisis
# running pubpager on https://www.mercatus.org/publications/process-reform-regulatory-impact-analysis
# Successfully extracted regulatory-process-and-ria-oct_2016_ellig-fike-final_typescript_mercatus.pdf
# Successfully extracted mercatus-ellig-regulatory-impact-analysis-summary-v1.pdf
# running pubpager on https://www.mercatus.org/publications/education-policymaking-bench-lessons-new-jersey-and-connecticut
# Successfully extracted primo_-_mop_-_constitutions_and_the_fiscal_health_of_states-new_jersey_-_v1.pdf
# running pubpager on https://ppe.mercatus.org/commentary/people-matter-social-element-disaster-response-and-recovery
# running pubpager on https://www.mercatus.org/publication/impartiality-political-participation-and-federal-budget-process-reform
# Successfully extracted Roth_Impartiality_final.pdf
# running pubpager on https://www.mercatus.org/publication/current-spending-cuts-insufficient-balance-budgets-long-run
# running pubpager on https://www.mercatus.org/publication/price-everything-parable-possibility-and-prosperity
# running pubpager on https://www.mercatus.org/publications/considerations-improved-pension-solvency-and-retirement-options-maryland
# Successfully extracted norcross-maryland-retirement-options-testimony-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/why-government-doubles-down-policy-mistakes
# running pubpager on https://www.mercatus.org/publications/dynamic-gains-free-digital-trade-us-economy
# Successfully extracted griswold_-_the_dynamic_gains_from_free_digital_trade_-_v1.pdf
# running pubpager on https://www.mercatus.org/commentary/trump-more-serious-you-think-about-building-border-wall
# running pubpager on https://www.mercatus.org/commentary/hurricane-doofonomics
# running pubpager on https://www.mercatus.org/publication/improving-efficiency-and-equity-highway-funding-and-management-role-vmt-charges
# Successfully extracted Miller_VMT_v1.pdf
# Successfully extracted Miller_VMT_summary_v1.pdf
# running pubpager on https://www.mercatus.org/commentary/riding-roller-coaster-economy-trump
# running pubpager on https://www.mercatus.org/publication/texas-sunset-advisory-commission
# Successfully extracted Texas-Sunset-Advisory-Commission-McTigue.pdf
# running pubpager on https://ppe.mercatus.org/publication/doing-right-things-private-sector-response-hurricane-katrina-case-study-bourgeois
# Successfully extracted WP0933_Hurricane Katrina and the Bourgeois Virtues.pdf
# running pubpager on https://www.mercatus.org/publication/most-fiscal-reforms-fail-lower-debt-gdp-ratio
# running pubpager on https://www.mercatus.org/commentary/feds-low-inflation-mystery-could-be-explained-one-simple-piece-tech
# running pubpager on https://www.mercatus.org/commentary/youre-gonna-need-bigger-virtual-wallet
# running pubpager on https://www.mercatus.org/commentary/republicans-bold-tax-moves-may-pay-later
# running pubpager on https://www.mercatus.org/publication/can-research-and-development-tax-credit-be-properly-designed-economic-efficiency
# Successfully extracted Fichtner-R-D-Tax-Credit.pdf
# Successfully extracted Fichtner-R-D-Tax-Credit-sum.pdf
# running pubpager on https://www.mercatus.org/publication/special-interest-sugar-policies-raise-costs-halloween-fun
# running pubpager on https://www.mercatus.org/publications/CLIA-waiver-pharmacy-growth
# Successfully extracted mercatus-timmons-healthcare-license-pharmacist-v1.pdf
# Successfully extracted mercatus-timmons-healthcare-license-pharmacist-sum-v1.pdf
# running pubpager on https://www.mercatus.org/publication/state-fiscal-crises-states-abilities-withstand-recessions
# Successfully extracted Mitchell-State-Fiscal-Crises.pdf
# Successfully extracted Mitchell_StateFiscalCrises-summary.pdf
# running pubpager on https://www.mercatus.org/publication/disaster-aid-spending-fema-s-track-record
# running pubpager on https://www.mercatus.org/publication/regulatory-reform-can-amount-progressive-tax-refund-if-done-right
# Successfully extracted McLaughlin-RegReform-testimony.pdf
# running pubpager on https://www.mercatus.org/publications/snapshot-missouri-regulation
# Successfully extracted broughel-snapshot-missouri-regulation-2017-brief-v1.pdf
# running pubpager on https://ppe.mercatus.org/publication/advanced-studies-political-economy
# running pubpager on https://www.mercatus.org/commentary/trump-attack-trade-deficit-could-harm-economy
# running pubpager on https://www.mercatus.org/commentary/new-populism-isnt-about-economics
# Could not find tags for https://www.mercatus.org/commentary/new-populism-isnt-about-economics
# running pubpager on https://www.mercatus.org/publication/alabama-crossroads-economic-guide-fiscally-sustainable-future-0
# Successfully extracted Dove-Alabama-v4.pdf
# Successfully extracted Dove-Alabama-sum-v2.pdf
# running pubpager on https://www.mercatus.org/commentary/raiding-taxpayers-pockets
# running pubpager on https://www.mercatus.org/publication/oira-quality-control-missing-most-regulations
# running pubpager on https://www.mercatus.org/commentary/deciphering-trumponomics-chapter-one
# running pubpager on https://www.mercatus.org/publication/using-government-streamlining-commissions-reduce-spending-and-improve-efficiency
# Successfully extracted Rothschild_testimony_Feb2011 (2).pdf
# running pubpager on https://www.mercatus.org/publications/high-speed-railways-economic-growth
# Successfully extracted mercatus-button-high-speed-railways-v1.pdf
# Successfully extracted mercatus-button-high-speed-railways-sum-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/health-care-laws-you-should-be-paying-attention-and-probably-arent
# running pubpager on https://www.mercatus.org/commentary/beware-bank-lobbying
# running pubpager on https://www.mercatus.org/publications/why-there-no-made-america-tax
# running pubpager on https://www.mercatus.org/publications/tax-policies-income-inequality-economic-opportunities
# Successfully extracted mercatus-swagel-tax-inequality-v1.pdf
# Successfully extracted mercatus-swagel-tax-inequality-summary-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/fed-needs-savvy-politician-its-chair
# running pubpager on https://www.mercatus.org/publication/spending-surge-seniors-medicare-and-social-security-total-50-percent-budget-2030
# running pubpager on https://www.mercatus.org/publications/snapshot-colorado-regulation-2017
# Successfully extracted broughel_and_francis_-_policy_brief_-_regulatory_snapshot_co_-_v1_1.pdf
# running pubpager on https://www.mercatus.org/publication/ending-federal-reserve-system-s-overreach-credit-allocation
# Successfully extracted White_Credit-Allocation-Fed_testimony_031114[1].pdf
# running pubpager on https://www.mercatus.org/commentary/senate-gop%E2%80%99s-dual-market-idea-postmortem-premortem
# running pubpager on https://www.mercatus.org/publication/government-performance-and-results
# running pubpager on https://www.mercatus.org/publication/government-financed-employment-and-real-private-sector-50-states
# running pubpager on https://www.mercatus.org/publications/matter-restoring-internet-freedom
# Successfully extracted skorup-restoring-internet-freedom-mercatus-comment-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/cryptocurrencies-dont-belong-central-banks
# running pubpager on https://www.mercatus.org/publication/fundamental-spending-reform-solution-debt-ceiling-debate
# Successfully extracted de-Rugy-Fundamental-Spending-Reform-Testimony-v1.pdf
# running pubpager on https://www.mercatus.org/publication/retrospective-analysis-regulations-implementing-nutrition-labeling-and-education-act
# Successfully extracted Williams-Nutrition-Label-Retrospective-Review-v1_1.pdf
# running pubpager on https://www.mercatus.org/publication/medicare-spending-source
# running pubpager on https://ppe.mercatus.org/publication/best-responders
# running pubpager on https://www.mercatus.org/publications/need-constitutional-budget-reform
# Successfully extracted primo-budget-reform-testimony-mercatus-v2.pdf
# running pubpager on https://www.mercatus.org/publication/cost-debt-drives-long-term-spending-explosion
# running pubpager on https://www.mercatus.org/publication/cato-institute-study-quantifies-ex-im-winners-and-losers
# running pubpager on https://www.mercatus.org/commentary/125-billion-people-were-shocked-november-8-2016
# running pubpager on https://www.mercatus.org/commentary/eclipse-2017-connectivity-and-farthest-reaching-party-ever
# running pubpager on https://www.mercatus.org/publication/update-top-foreign-buyers-us-exports-subsidized-export-import-bank
# running pubpager on https://www.mercatus.org/publication/dodd-frank-wall-street-reform-and-consumer-protection-act-may-be-biggest-law-ever
# running pubpager on https://www.mercatus.org/commentary/how-wall-street-innovations-cost-taxpayers-millions
# running pubpager on https://www.mercatus.org/commentary/trumps-war-leaks-might-bring-more-chaos-not-less
# running pubpager on https://www.mercatus.org/publications/local-governments-economic-freedom-leviathan
# Successfully extracted millsap-leviathan-hypothesis-mercatus-working-paper-v2.pdf
# Successfully extracted millsap-leviathan-hypothesis-mercatus-summary-v2.pdf
# running pubpager on https://www.mercatus.org/publication/setting-governmental-accounting-standards-michigan-fiscal-distress
# Successfully extracted Convery-Governmental-Accounting.pdf
# Successfully extracted Convery-Governmental-Accounting-summary.pdf
# running pubpager on https://www.mercatus.org/commentary/detroit-plays-games-school-funding
# running pubpager on https://www.mercatus.org/publication/introduction-us-monetary-policy
# Successfully extracted Horwitz_MonetaryPolicy_v2.pdf
# Successfully extracted Horwitz-Intro-Monetary-Policy-sum-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/uk-needs-second-glorious-revolution-only-calmer
# running pubpager on https://www.mercatus.org/commentary/time-re-examine-outdated-regulations
# running pubpager on https://www.mercatus.org/publication/beyond-silk-road-potential-risks-threats-and-promises-virtual-currencies
# Successfully extracted Brito_BeyondSilkRoadBitcoin_testimony_111313.pdf
# running pubpager on https://www.mercatus.org/publication/federal-government-autopilot-delegation-regulatory-authority-unaccountable-bureaucracy
# Successfully extracted Graham-Testimony-May-2016-v1.pdf
# running pubpager on https://www.mercatus.org/publication/competitive-sourcing-government
# Successfully extracted McTigue-Competitive-Sourcing-House-OGR-Testimony-July-2016-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/inflation-valuable-tool-too-bad-we-cant-use-it
# running pubpager on https://www.mercatus.org/publication/public-interest-comment-train-crew-staffing-rule
# Successfully extracted McLaughlin-FRA-Crew-Size-Rule-v1.pdf
# running pubpager on https://www.mercatus.org/commentary/reining-wisconsin-regulations
# running pubpager on https://www.mercatus.org/publication/assessing-department-energy-loan-guarantee-program
# Successfully extracted DeRugy_testimony_final.pdf
# running pubpager on https://www.mercatus.org/publications/regulations-increase-mortality-risk
# Successfully extracted broughel-life-saving-regulations-wp-mercatus-v3.pdf
# Successfully extracted broughel-life-saving-regulations-sum-mercatus-v2.pdf
# running pubpager on https://www.mercatus.org/publication/did-deregulation-cause-financial-crisis-examining-common-justification-dodd-frank
# running pubpager on https://www.mercatus.org/commentary/robert-graboyes-alexander-murray-deal
# running pubpager on https://www.mercatus.org/commentary/opioid-problem-employment-problem
# running pubpager on https://www.mercatus.org/commentary/carried-interest-tax-carry-water-reform
# running pubpager on https://ppe.mercatus.org/publication/market-theory-and-price-system
# running pubpager on https://www.mercatus.org/publication/transforming-department-homeland-security-through-mission-based-budgeting
# Successfully extracted MC_GAP_McTigueTestimony_050629.pdf
# running pubpager on https://www.mercatus.org/publication/export-import-bank-winners-and-losers-government-granted-privilege
# Successfully extracted DeRugy-Ex-Im-Banking-Testimony.pdf
# running pubpager on https://www.mercatus.org/publications/fdic-guidance-third-party-lending
# Successfully extracted mercatus-fdic-guidance-third-party-lending.pdf
# running pubpager on https://www.mercatus.org/commentary/exposing-government-favoritism
# running pubpager on https://www.mercatus.org/publication/effects-sequestration-federal-spending
# running pubpager on https://www.mercatus.org/commentary/congress-must-heel-rogue-financial-watchdog
# running pubpager on https://www.mercatus.org/publications/reforming-us-immigration-system-economic-growth
# Successfully extracted griswold-immigration-reform-mercatus-research-v1.pdf
# Successfully extracted griswold-immigration-reform-mercatus-summary-v1.pdf
# running pubpager on https://www.mercatus.org/publication/economic-situation-june-2015
# Successfully extracted Yandle-June-2015-Economic-Situation.pdf
# running pubpager on https://www.mercatus.org/publications/permissionless-innovation-virtual-reality-VR
# Successfully extracted thierer-immersive-technology-mercatus-working-paper-v1.pdf
# Successfully extracted thierer-immersive-technology-mercatus-summary-v1.pdf
# running pubpager on https://www.mercatus.org/publication/status-update-development-voluntary-do-not-track-standards
# Successfully extracted Thierer_testimony_DNT_042313.pdf
# running pubpager on https://www.mercatus.org/commentary/florida-defies-big-state-financial-curse
# ...
# Successfully extracted WP0904_GAP_Spending-Under-President-George-W-Bush_v2.pdf
# running pubpager on https://www.mercatus.org/publication/sunset-legislation-states-balancing-legislature-and-executive
# Successfully extracted Baugus-Sunset-Legislation.pdf
# Successfully extracted Baugus-Sunset-Legislation-summary.pdf
# running pubpager on https://asp.mercatus.org/publication/sin-taxes-and-sindustry-revenue-paternalism-and-political-interest
# Could not find tags for https://asp.mercatus.org/publication/sin-taxes-and-sindustry-revenue-paternalism-and-political-interest
# running pubpager on https://www.mercatus.org/publication/spending-share-gdp
# running pubpager on https://www.mercatus.org/publication/epas-ground-water-rule
# Successfully extracted Ground_Water_Rule.pdf
# running pubpager on https://www.mercatus.org/publication/certificate-need-laws-implications-florida
# Successfully extracted Koopman-Certificate-of-NeedFL-MOP.pdf
# running pubpager on https://www.mercatus.org/publication/challenge-benefit-cost-analysis-applied-online-safety-digital-privacy
# running pubpager on https://www.mercatus.org/publication/epas-phase-iii-cooling-water-intake-structures-proposed-rule2
# Successfully extracted MC_RSP_PIC2005-02EPACVPhaseIIIManuf_050324(1).pdf
# running pubpager on https://www.mercatus.org/publication/law-and-economics-shareholder-voting-reform-and-costs-proxy-access
# Successfully extracted ProxyAccess_Verret_Stratmann1.17.12.pdf
# running pubpager on https://www.mercatus.org/publication/economic-situation-december-2014
# Successfully extracted Yandle-Econ-report-Dec-2014.pdf
# running pubpager on https://www.mercatus.org/commentary/every-trade-deal-needs-referee
# running pubpager on https://www.mercatus.org/publication/perils-classifying-social-media-platforms-public-utilities-0
# Successfully extracted Perils-of-Classifying-Social-Media-Platforms-Public-Utilities.pdf
# running pubpager on https://www.mercatus.org/publication/unintended-consequences-safety-regulation
# Successfully extracted Abdukadirov_UnintendedConsequences_v1.pdf
# running pubpager on https://ppe.mercatus.org/publication/austrian-economics-perspective-transitional-political-economy
# running pubpager on https://ppe.mercatus.org/publication/do-pessimistic-assumptions-about-human-behavior-justify-government-0
# Could not find tags for https://ppe.mercatus.org/publication/do-pessimistic-assumptions-about-human-behavior-justify-government-0
# running pubpager on https://ppe.mercatus.org/publication/complexity-governance-and-constitutional-craftsmanship
# Could not find tags for https://ppe.mercatus.org/publication/complexity-governance-and-constitutional-craftsmanship
# running pubpager on https://www.mercatus.org/publication/airport-pricing
# Successfully extracted 200804021_pic_on_airport_fees_policy_statement_final(1).pdf
# running pubpager on https://www.mercatus.org/publication/net-interest-rivals-general-spending-2040
# running pubpager on https://www.mercatus.org/commentary/cbo-shows-how-repeal-aca-regulations
# running pubpager on https://www.mercatus.org/publication/politics-wine-trade-barriers-interest-groups-and-commerce-clause
# Successfully extracted 20070705_the_politics_of_wine_-_wiseman_ellig_jop2007.pdf
# running pubpager on https://www.mercatus.org/publication/objective-risk
# Successfully extracted Shamoun-On-Objective-Risk_0.pdf
# Successfully extracted Shamoun-On-Objective-Risk-sum-v2.pdf
# running pubpager on https://www.mercatus.org/publication/putting-price-performance-demonstration-study-outcome-based-scrutiny
# Successfully extracted MC_GAP_PriceonPerformance_001201.pdf
# running pubpager on https://www.mercatus.org/publication/responding-agency-avoidance-oira
# running pubpager on https://www.mercatus.org/publication/cost-regulations-implementing-clean-water-act
# Successfully extracted cost-regulations-implementing-clean-water-act.pdf
# running pubpager on https://ppe.mercatus.org/publication/economic-uncertainty-courts-and-rule-law
# Could not find tags for https://ppe.mercatus.org/publication/economic-uncertainty-courts-and-rule-law
# running pubpager on https://ppe.mercatus.org/publication/foreign-intervention-police-militarization-and-minorities
# Could not find tags for https://ppe.mercatus.org/publication/foreign-intervention-police-militarization-and-minorities
# running pubpager on https://asp.mercatus.org/publication/economics-immigration-market-based-approaches-social-science-and-public-policy
# running pubpager on https://www.mercatus.org/publication/public-debt-under-various-fy-2014-proposals
# running pubpager on https://www.mercatus.org/publication/price-effects-and-commerce-clause-case-state-wine-shipping-laws
# running pubpager on https://www.mercatus.org/publication/taxing-sin
# Successfully extracted MOP55-_Taxing-Sin_web_fixed.pdf
# running pubpager on https://www.mercatus.org/publication/tax-units-paying-no-income-tax
# running pubpager on https://www.mercatus.org/publication/millionaires-unlikely-stay-millionaires-long
# running pubpager on https://www.mercatus.org/publication/mercatus-policy-using-economics-experiments-evaluate-tort-reform-proposals
# Successfully extracted tort4pager.pdf
# running pubpager on https://www.mercatus.org/publication/economic-situation-december-2012
# running pubpager on https://www.mercatus.org/publication/budget-gimmicks-or-destructive-art-creative-accounting-0
# Successfully extracted Budget Gimmicks Research Summary de Rugy (2).pdf
# running pubpager on https://www.mercatus.org/publication/economic-situation-september-2013
# Successfully extracted Yandle_EconomicSituationSept2013_082913_1.pdf
# running pubpager on https://www.mercatus.org/publication/uncreative-destruction-misguided-war-vertical-integration-information-economy
# Successfully extracted Uncreative-Destruction---The-War-on-Vertical-Integration-in-the-Info-Economy---Brent-Skorup-&amp;-Adam-Thierer-(65-Fed-Comm-Law-Jour---April-2012).pdf
# running pubpager on https://www.mercatus.org/publication/share-federal-taxes-under-current-law
# running pubpager on https://www.mercatus.org/publication/taxing-sins-are-excise-taxes-efficient
# Successfully extracted RSP_MOP52_Taxing_Sins_web.pdf
# running pubpager on https://www.mercatus.org/publication/dedicating-tax-revenue-constraining-government-or-masking-its-growth
# Successfully extracted Dedicating-Tax-Revenue.pdf
# Successfully extracted Crowley-Dedicating-Tax-Revenue-summary.pdf
# running pubpager on https://www.mercatus.org/publication/bank-risk-management
# Successfully extracted MOP_-_Bank_Risk_Management_(04-14-2009).pdf
# running pubpager on https://www.mercatus.org/publication/federal-workforce-trend-2001-2010
# running pubpager on https://www.mercatus.org/publication/decision-making-101-regulatory-impact-analysis
# running pubpager on https://www.mercatus.org/publication/new-role-fda-food-safety
# Successfully extracted wp1069-a-new-role-for-the-fda.pdf
# running pubpager on https://www.mercatus.org/commentary/seth-chandlers-reaction-house-republicans-health-care-plan
# running tagcontroller
# running tagpager on https://www.mercatus.org/tags/constitutional-political-economy
# running pubcontroller
# running pubpager on https://ppe.mercatus.org/publication/book-chapter-economic-effects-international-labor-mobility
# running pubpager on https://www.mercatus.org/publication/jobs-jobs-jobs-where-do-jobs-come
# Successfully extracted Jobs.WP_.Yandle.1.27.10_1.pdf
# Successfully extracted Jobs, Jobs.Executive Summary.Yandle 2.20.11_0.pdf
# running pubpager on https://www.mercatus.org/publication/economic-situation-june-2014
# Successfully extracted Yandle_EconomicSituation_June2014.pdf
# running pubpager on https://www.mercatus.org/publication/osha-consultation-agreements
# MYSTERY??? ERROR OCCURRED ON Consultation-Agreement.pdf
# running pubpager on https://www.mercatus.org/publication/controlling-federal-spending-using-past-budgets-guides-spending-restraint
# Successfully extracted Controlling Federal Spending. Garen.pdf
# running pubpager on https://www.mercatus.org/publication/getting-accurate-picture-state-pension-liabilities
# Successfully extracted Getting-an-Accurate-Picture-of-State-Pension-Liablilities.Norcross.12.13.10.pdf
# running pubpager on https://www.mercatus.org/publication/public-interest-comment-food-and-drug-administration-and-first-amendment-issues
# Successfully extracted Food-and-Drug-Administration-and-First-Amendment-Issues_0.pdf
# running pubpager on https://www.mercatus.org/publication/affordable-care-act-and-new-economics-part-time-work
# Successfully extracted Mulligan-ACA-Part-TimeWork.pdf
# Successfully extracted Mulligan-ACA-Part-Time-Work-summary.pdf
# running pubpager on https://ppe.mercatus.org/publication/oxford-handbook-austrian-economics
# running pubpager on https://www.mercatus.org/publication/transparency-and-performance-government
# Successfully extracted Brito and Perraut v11 161-194.pdf
# running pubpager on https://www.mercatus.org/publication/us-sovereign-debt-crisis-tipping-point-scenarios-and-crash-dynamics/how-default-might-0
# Bailing out; error fetching basics on https://www.mercatus.org/publication/us-sovereign-debt-crisis-tipping-point-scenarios-and-crash-dynamics/how-default-might-0
# running pubpager on https://www.mercatus.org/publication/municipal-fiscal-emergency-laws-background-and-guide-state-based-approaches
# Successfully extracted Scorsone-Municipal-Fiscal-Emergency_0.pdf
# Successfully extracted Scorsone-Municipal-Fiscal-Emergency-summary.pdf
# running pubpager on https://www.mercatus.org/publication/sec-regulhttps://www.mercatus.org/publication/sec-regulatory-analysis-long-way-go-and-short-time-get-thereatory-analysis-long-way-go-and-short-time-get-there
# Bailing out; error fetching basics on https://www.mercatus.org/publication/sec-regulhttps://www.mercatus.org/publication/sec-regulatory-analysis-long-way-go-and-short-time-get-thereatory-analysis-long-way-go-and-short-time-get-there
# running pubpager on https://www.mercatus.org/publication/benefits-and-costs-oshas-proposed-ergonomics-program-standard
# running pubpager on https://www.mercatus.org/publication/improving-measures-environmental-justice-epa-regulatory-analysis
# Successfully extracted Broughel_Environmental-Justice_presentation_012314[1].pdf
# running pubpager on https://www.mercatus.org/commentary/scaling-up
# running pubpager on https://www.mercatus.org/publication/food-safety-21st-century
# Successfully extracted MOP71_Food Safety_web.pdf
# running pubpager on https://www.mercatus.org/publications/are-low-interest-rates-natural-or-artificial
# Bailing out; error fetching basics on https://www.mercatus.org/publications/are-low-interest-rates-natural-or-artificial
# running pubpager on https://www.mercatus.org/publication/debt-ceiling-what-stake
# Successfully extracted Debt-Ceiling.deRugy.Fichtner.4.28.11.pdf
# running pubpager on https://www.mercatus.org/publication/fy-2014-budget-proposals
# Successfully extracted FY14-Budget_economic-perspectives_03142013.pdf
# running pubpager on https://www.mercatus.org/publication/debt-limit-debate
# Successfully extracted Debt Limit.MoP_.Fichtner.deRugy.5.26.11.pdf
# running pubpager on https://www.mercatus.org/publication/harnessing-markets-improve-water-quality
# running pubpager on https://www.mercatus.org/publication/relationship-between-taxpayers-and-tax-spenders
# Successfully extracted Taxpayers_and_Tax_Spenders_Lipford_Yandle_WP1129_0.pdf
# running pubpager on https://www.mercatus.org/commentary/masking-real-tax-burden
# running pubpager on https://www.mercatus.org/publication/stimulusfacts
# Bailing out; error fetching basics on https://www.mercatus.org/publication/stimulusfacts
# running pubpager on https://www.mercatus.org/publication/has-gpra-increased-availability-and-use-performance-information
# Successfully extracted wp0903-has-gpra-increased-performance-information.pdf
# running pubpager on https://ppe.mercatus.org/publication/taxes-lawyers-and-decline-witch-trials-france-0
# Could not find tags for https://ppe.mercatus.org/publication/taxes-lawyers-and-decline-witch-trials-france-0
# running pubpager on https://www.mercatus.org/publications/four-ways-increasing-interest-rates
# running pubpager on https://www.mercatus.org/publication/companies-reluctant-spend-uncertain-regulatory-environment
# running pubpager on https://www.mercatus.org/publication/fdas-trans-fat-labeling
# Successfully extracted Trans Fat.pdf
# running pubpager on https://www.mercatus.org/publication/solving-food-safety-problems-without-antiquated-regulation-and-inspection
# Successfully extracted Williams_final.pdf
# running pubpager on https://www.mercatus.org/publications/nudges-health-care
# running pubpager on https://www.mercatus.org/publication/economic-situation-september-2014
# Successfully extracted Yandle_Economic-Situation_Sept-2014.pdf
# Could not find tags for https://www.mercatus.org/publication/economic-situation-september-2014
# running pubpager on https://www.mercatus.org/publication/reality-isnt-negotiable-government-cant-raise-more-19-taxes-long
# running pubpager on https://www.mercatus.org/publication/evaluating-oshas-effectiveness-and-suggestions-reform
# Successfully extracted Hale_OSHA_MOP_041913.pdf
# running pubpager on https://www.mercatus.org/commentary/getting-personal
# running pubpager on https://ppe.mercatus.org/publication/form-vs-substance-selection-through-competition-elections-markets-and-political-econom-0
# Could not find tags for https://ppe.mercatus.org/publication/form-vs-substance-selection-through-competition-elections-markets-and-political-econom-0
# running pubpager on https://www.mercatus.org/commentary/right-way-pay-tax-reform
# running pubpager on https://www.mercatus.org/publication/ratcheting-taxes
# Successfully extracted Do Intergovernmental Grants.MoP_.Sobel_.10.25.pdf
# running pubpager on https://www.mercatus.org/publication/10th-annual-performance-report-scorecard-which-federal-agencies-best-inform-public
# Successfully extracted 10th_Annual_Performance_Report_Scorecard.pdf
# running pubpager on https://www.mercatus.org/publication/artifact-law-us-prohibition-retail-hedge-funds
# running pubcontroller
# running pubpager on https://www.mercatus.org/publication/epas-economic-incentive-program-guidance
# MYSTERY??? ERROR OCCURRED ON EPAs-Economic.pdf
# running pubpager on https://www.mercatus.org/publication/do-intergovernmental-grants-create-ratchets-state-and-local-taxes-0
# Successfully extracted Sobel_Research_Summary.pdf
# running pubpager on https://ppe.mercatus.org/publication/book-chapter-tax-state-source-perpetual-crisis
# running pubpager on https://ppe.mercatus.org/publication/book-chapter-market-process-theory-perspective-capitalism
# running pubpager on https://www.mercatus.org/commentary/why-trump-right-oppose-part-house-gop-tax-plan
# running pubpager on https://www.mercatus.org/commentary/theres-nothing-simple-about-hiding-burden-taxes
# running pubpager on https://www.mercatus.org/publication/federal-infrastructure-spen
# Bailing out; error fetching basics on https://www.mercatus.org/publication/federal-infrastructure-spen
# running pubpager on https://www.mercatus.org/publications/healthcare-research-toolkit
# Could not find tags for https://www.mercatus.org/publications/healthcare-research-toolkit
# running pubpager on https://www.mercatus.org/publication/epa-and-dojs-worst-case-scenario-proposal
# MYSTERY??? ERROR OCCURRED ON Off-Site-Consequence-Analysis-Information.pdf
# running pubpager on https://www.mercatus.org/publication/ombs-2007-report-congress-cost-and-benefits-federal-regulations
# Successfully extracted 20070914_omb_peer_all_changes_final_-_9-05-07_format(1).pdf
# running pubpager on https://ppe.mercatus.org/publication/book-chapter-introduction
# running pubpager on https://www.mercatus.org/commentary/vision-innovation
# running pubcontroller
# running pubpager on https://www.mercatus.org/publication/draft-supporting-materials-science-advisory-board-panel-role-economy-wide-modeling-us
# Successfully extracted Hall_EPA_materials-for-SAB_PIC_040714.pdf
# running pubpager on https://www.mercatus.org/commentary/lame-ducks-and-corporate-tax-privileges
